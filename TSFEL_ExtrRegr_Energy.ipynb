# %%
# !pip install tsfel
# Out:
# Requirement already satisfied: tsfel in c:\users\tretec\documents\mva\s1\[ast]\tsfel_review\.venv\lib\site-packages (0.1.6)
# Requirement already satisfied: ipython>=7.4.0 in c:\users\tretec\documents\mva\s1\[ast]\tsfel_review\.venv\lib\site-packages (from tsfel) (8.19.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\tretec\documents\mva\s1\[ast]\tsfel_review\.venv\lib\site-packages (from tsfel) (1.26.3)
# Requirement already satisfied: pandas>=1.5.3 in c:\users\tretec\documents\mva\s1\[ast]\tsfel_review\.venv\lib\site-packages (from tsfel) (2.1.4)
# Requirement already satisfied: scipy>=1.7.3 in c:\users\tretec\documents\mva\s1\[ast]\tsfel_review\.venv\lib\site-packages (from tsfel) (1.11.4)
# Requirement already satisfied: setuptools>=47.1.1 in c:\users\tretec\documents\mva\s1\[ast]\tsfel_review\.venv\lib\site-packages (from tsfel) (65.5.0)
# Requirement already satisfied: decorator in c:\users\tretec\documents\mva\s1\[ast]\tsfel_review\.venv\lib\site-packages (from ipython>=7.4.0->tsfel) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\tretec\documents\mva\s1\[ast]\tsfel_review\.venv\lib\site-packages (from ipython>=7.4.0->tsfel) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\tretec\documents\mva\s1\[ast]\tsfel_review\.venv\lib\site-packages (from ipython>=7.4.0->tsfel) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\tretec\documents\mva\s1\[ast]\tsfel_review\.venv\lib\site-packages (from ipython>=7.4.0->tsfel) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\tretec\documents\mva\s1\[ast]\tsfel_review\.venv\lib\site-packages (from ipython>=7.4.0->tsfel) (2.17.2)
# Requirement already satisfied: stack-data in c:\users\tretec\documents\mva\s1\[ast]\tsfel_review\.venv\lib\site-packages (from ipython>=7.4.0->tsfel) (0.6.3)
# Requirement already satisfied: traitlets>=5 in c:\users\tretec\documents\mva\s1\[ast]\tsfel_review\.venv\lib\site-packages (from ipython>=7.4.0->tsfel) (5.14.1)
# Requirement already satisfied: colorama in c:\users\tretec\documents\mva\s1\[ast]\tsfel_review\.venv\lib\site-packages (from ipython>=7.4.0->tsfel) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tretec\documents\mva\s1\[ast]\tsfel_review\.venv\lib\site-packages (from pandas>=1.5.3->tsfel) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tretec\documents\mva\s1\[ast]\tsfel_review\.venv\lib\site-packages (from pandas>=1.5.3->tsfel) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\tretec\documents\mva\s1\[ast]\tsfel_review\.venv\lib\site-packages (from pandas>=1.5.3->tsfel) (2023.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\tretec\documents\mva\s1\[ast]\tsfel_review\.venv\lib\site-packages (from jedi>=0.16->ipython>=7.4.0->tsfel) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\tretec\documents\mva\s1\[ast]\tsfel_review\.venv\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.4.0->tsfel) (0.2.13)
# Requirement already satisfied: six>=1.5 in c:\users\tretec\documents\mva\s1\[ast]\tsfel_review\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.5.3->tsfel) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\tretec\documents\mva\s1\[ast]\tsfel_review\.venv\lib\site-packages (from stack-data->ipython>=7.4.0->tsfel) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\tretec\documents\mva\s1\[ast]\tsfel_review\.venv\lib\site-packages (from stack-data->ipython>=7.4.0->tsfel) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\tretec\documents\mva\s1\[ast]\tsfel_review\.venv\lib\site-packages (from stack-data->ipython>=7.4.0->tsfel) (0.2.2)

# %%
from tqdm import tqdm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xgboost as xgb
from sklearn.model_selection import RandomizedSearchCV, train_test_split
import tsfel

from custom_code.utils import load_from_tsfile_to_dataframe

# %% [markdown]
# # Loading data from tseregression.org

# %%
TRAIN_PATH = 'regression_data/AppliancesEnergy_TRAIN.ts'
TEST_PATH = 'regression_data/AppliancesEnergy_TEST.ts'

# %%
Ts = 600 #s
fs = 1/Ts

# %%
fs=0.0016

# %%
X_train, y_train = load_from_tsfile_to_dataframe(TRAIN_PATH)
X_test, y_test = load_from_tsfile_to_dataframe(TEST_PATH)
# Out:
# 25it [00:00, 145.58it/s]
# 119it [00:08, 14.05it/s]
# 66it [00:03, 20.28it/s]

# %%
X_train.columns
# Out:
# Index(['dim_0', 'dim_1', 'dim_2', 'dim_3', 'dim_4', 'dim_5', 'dim_6', 'dim_7',
#        'dim_8', 'dim_9', 'dim_10', 'dim_11', 'dim_12', 'dim_13', 'dim_14',
#        'dim_15', 'dim_16', 'dim_17', 'dim_18', 'dim_19', 'dim_20', 'dim_21',
#        'dim_22', 'dim_23'],
#       dtype='object')

# %%
dimensions =X_train.columns
columns =['T1', 'RH_1', 'T2', 'RH_2', 'T3', 'RH_3', 'T4',
       'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8', 'RH_8', 'T9',
       'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed', 'Visibility',
       'Tdewpoint']
replace_by=dict(list(zip(dimensions,columns)))
X_train.rename(columns=replace_by,inplace=True)

# %%
X_test.rename(columns=replace_by,inplace=True)

# %% [markdown]
# # 1. Exploratory Data Analysis

# %%
data = X_train.copy()
sample = data.iloc[0]
sample[0].index.hour
# Out:
# C:\Users\TRETEC\AppData\Local\Temp\ipykernel_11992\2749409332.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sample[0].index.hour
# Index([17, 17, 17, 17, 17, 17, 18, 18, 18, 18,
#        ...
#        15, 15, 15, 15, 16, 16, 16, 16, 16, 16],
#       dtype='int32', length=144)

# %%
time_range = pd.date_range(start='17:00', periods=24, freq='H')

# %% [markdown]
# Visually comparing two multivariate time series with different target values

# %%
import matplotlib.dates as mdates
import matplotlib.colors as mcolors
import matplotlib.cm as cm


#First row in our trainset, a multivariate time series of 24 dimensions
samples = X_train.iloc[:2]


# Normalize y_train to a 0-1 scale
norm = mcolors.Normalize(vmin=min(y_train), vmax=max(y_train))

# Choose a colormap
cmap = cm.coolwarm #the cooler the color, the less energy consumed

fig, axes = plt.subplots(nrows=24, ncols=2, figsize=(12,20))
fig.tight_layout(w_pad=2)

for (j,sample) in list(samples.iterrows()):
    color = cmap(norm(y_train[j]))

    for i in range(24):
        axes[i,j].plot(sample[i],color=color)
        axes[i,j].set_ylabel(columns[i])
        axes[i,j].xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
    axes[0,j].set_title(f'Sample {j}, Daily consumed energy : {y_train[j]} kWh')
# Out:
# C:\Users\TRETEC\AppData\Local\Temp\ipykernel_11992\2839592146.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   axes[i,j].plot(sample[i],color=color)

# %%
data.insert(0,'start_recording',data['T1'].apply(lambda x:x.index[0]))
data.insert(1,'end_recording',data['T1'].apply(lambda x:x.index[-1]))

# %%
#creating new features
data['month'] = data.end_recording.apply(lambda x:x.month)
data['weekday'] = data.end_recording.apply(lambda x:x.weekday)
data['hour'] = data.end_recording.apply(lambda x:x.hour)
data['day'] = data.end_recording.apply(lambda x:x.day)
data['day_of_week'] = data.end_recording.apply(lambda x:x.dayofweek)

# %%
data['y'] = y_train

# %%
# Create a pivot table to aggregate the daily energy consumption
daily_energy = data.pivot_table(values='y', index='day', columns='month')

# Create a heatmap using the pivot table
plt.figure(figsize=(10, 5))
plt.title('Daily Energy Consumption')
plt.xlabel('Month')
plt.ylabel('Day')
plt.imshow(daily_energy, cmap='coolwarm', aspect='auto')
plt.colorbar(label='Energy Consumption')
plt.xticks(range(0,5), ['Jan', 'Feb', 'Mar', 'Apr', 'May'])
plt.yticks(range(1, 32))
plt.show()

# %% [markdown]
# # Feature extraction : TSFEL

# %% [markdown]
# ## Testing custom feature

# %%
#Custom feature : is_it_weekend
cfg_custom = tsfel.get_features_by_domain(json_path='custom_code/features.json')
# cfg_custom['temporal']['is_it_weekend']
cfg_custom = {'temporal':{'is_it_weekend':cfg_custom['temporal']['is_it_weekend']}}

# %%
cfg_custom
# Out:
# {'temporal': {'is_it_weekend': {'complexity': 'constant',
#    'description': '',
#    'function': 'is_it_weekend',
#    'parameters': {'parameters': None},
#    'use': 'yes'}}}

# %%
tsfel.time_series_features_extractor(cfg_custom, X_train.iloc[5, 0], fs=fs, features_path='C:\\Users\\TRETEC\\Documents\\MVA\\S1\\[AST]\\TSFEL_Review\\custom_code\\custom_feature.py')
# Out:
# *** Feature extraction started ***
# c:\Users\TRETEC\Documents\MVA\S1\[AST]\TSFEL_Review\.venv\Lib\site-packages\tsfel\feature_extraction\calc_features.py:265: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif isinstance(signal_windows[0], pd.DataFrame):
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='1'
#                   max='1',
#                   style='width: 25%',
#               >
#                   1
#               </progress>
# *** Feature extraction finished ***
#    0_is_it_weekend
# 0                0

# %% [markdown]
# Good news is our custom feature has been successfully added. Bad news is tsfel isnt very flexible regarding input data format and feature calculation :
# 1. time series that get fed to ``tsfel.time_series_features_extractor`` are automatically converted to np.array, allowing only to store time_series values but not corresponding time index. But the latter could sometimes be helpful, for extracting seasonal features.
# 2. window_size argument in ``tsfel.time_series_features_extractor`` is in fact related to the samples dimension and not the temporal dimension, this is to be used when we classify segments of a time series.
#
# We also notice that it is somewhat laborious to extract a single specific feature (there is no options to *directly* extract features `by_id`, only in groups)

# %% [markdown]
# ## TSFEL built-in features

# %%
# Get the TSFEL feature configuration
import pandas as pd
cfg = tsfel.get_features_by_domain()

# %%
# Extract features for each variable and concatenate them
X_train_features = []
for dim in tqdm(range(X_train.shape[1])): #iterate over dimensions
    temp_features = tsfel.time_series_features_extractor(cfg, [X_train.iloc[i, dim] for i in range(X_train.shape[0])], fs=fs)
    X_train_features.append(temp_features)

X_train_features = pd.concat(X_train_features, axis=1)
X_train_features
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='95'
#                   max='95',
#                   style='width: 25%',
#               >
#                   95
#               </progress>
#   4%|▍         | 1/24 [00:07<03:01,  7.89s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='95'
#                   max='95',
#                   style='width: 25%',
#               >
#                   95
#               </progress>
#   8%|▊         | 2/24 [00:14<02:35,  7.07s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='95'
#                   max='95',
#                   style='width: 25%',
#               >
#                   95
#               </progress>
#  12%|█▎        | 3/24 [00:21<02:26,  6.98s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='95'
#                   max='95',
#                   style='width: 25%',
#               >
#                   95
#               </progress>
#  17%|█▋        | 4/24 [00:29<02:29,  7.50s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='95'
#                   max='95',
#                   style='width: 25%',
#               >
#                   95
#               </progress>
#  21%|██        | 5/24 [00:37<02:23,  7.54s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='95'
#                   max='95',
#                   style='width: 25%',
#               >
#                   95
#               </progress>
#  25%|██▌       | 6/24 [00:45<02:18,  7.68s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='95'
#                   max='95',
#                   style='width: 25%',
#               >
#                   95
#               </progress>
#  29%|██▉       | 7/24 [00:52<02:08,  7.58s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='95'
#                   max='95',
#                   style='width: 25%',
#               >
#                   95
#               </progress>
#  33%|███▎      | 8/24 [00:58<01:51,  6.97s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='95'
#                   max='95',
#                   style='width: 25%',
#               >
#                   95
#               </progress>
#  38%|███▊      | 9/24 [01:04<01:39,  6.66s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='95'
#                   max='95',
#                   style='width: 25%',
#               >
#                   95
#               </progress>
#  42%|████▏     | 10/24 [01:10<01:33,  6.67s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='95'
#                   max='95',
#                   style='width: 25%',
#               >
#                   95
#               </progress>
#  46%|████▌     | 11/24 [01:16<01:21,  6.30s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='95'
#                   max='95',
#                   style='width: 25%',
#               >
#                   95
#               </progress>
#  50%|█████     | 12/24 [01:22<01:15,  6.30s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='95'
#                   max='95',
#                   style='width: 25%',
#               >
#                   95
#               </progress>
#  54%|█████▍    | 13/24 [01:29<01:11,  6.47s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='95'
#                   max='95',
#                   style='width: 25%',
#               >
#                   95
#               </progress>
#  58%|█████▊    | 14/24 [01:38<01:13,  7.39s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='95'
#                   max='95',
#                   style='width: 25%',
#               >
#                   95
#               </progress>
#  62%|██████▎   | 15/24 [01:46<01:08,  7.57s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='95'
#                   max='95',
#                   style='width: 25%',
#               >
#                   95
#               </progress>
#  67%|██████▋   | 16/24 [01:55<01:02,  7.77s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='95'
#                   max='95',
#                   style='width: 25%',
#               >
#                   95
#               </progress>
#  71%|███████   | 17/24 [02:03<00:56,  8.08s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='95'
#                   max='95',
#                   style='width: 25%',
#               >
#                   95
#               </progress>
#  75%|███████▌  | 18/24 [02:12<00:49,  8.22s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='95'
#                   max='95',
#                   style='width: 25%',
#               >
#                   95
#               </progress>
#  79%|███████▉  | 19/24 [02:23<00:44,  8.97s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='95'
#                   max='95',
#                   style='width: 25%',
#               >
#                   95
#               </progress>
#  83%|████████▎ | 20/24 [02:32<00:36,  9.14s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='95'
#                   max='95',
#                   style='width: 25%',
#               >
#                   95
#               </progress>
#  88%|████████▊ | 21/24 [02:41<00:27,  9.11s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='95'
#                   max='95',
#                   style='width: 25%',
#               >
#                   95
#               </progress>
#  92%|█████████▏| 22/24 [02:49<00:17,  8.76s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='95'
#                   max='95',
#                   style='width: 25%',
#               >
#                   95
#               </progress>
#  96%|█████████▌| 23/24 [02:56<00:08,  8.27s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='95'
#                   max='95',
#                   style='width: 25%',
#               >
#                   95
#               </progress>
# 100%|██████████| 24/24 [03:03<00:00,  7.64s/it]
# *** Feature extraction finished ***
#     0_Absolute energy  0_Area under the curve  0_Autocorrelation  \
# 0        58010.444042            1.791287e+06       58010.444042
# 1        65302.514112            1.902397e+06       65302.514112
# 2        49171.064642            1.650655e+06       49171.064642
# 3        62981.336469            1.867788e+06       62981.336469
# 4        66518.752034            1.919477e+06       66518.752034
# ..                ...                     ...                ...
# 90       67199.664458            1.929427e+06       67199.664458
# 91       85668.469928            2.178651e+06       85668.469928
# 92       60350.306881            1.828613e+06       60350.306881
# 93       59983.244269            1.823376e+06       59983.244269
# 94       61833.865019            1.850757e+06       61833.865019
#
#     0_Average power    0_Centroid  0_ECDF Percentile Count_0  \
# 0          0.649068  44442.819779                       28.0
# 1          0.730658  43463.412120                       28.0
# 2          0.550166  43299.938547                       28.0
# 3          0.704686  44690.245306                       28.0
# 4          0.744266  43234.671465                       28.0
# ..              ...           ...                        ...
# 90         0.751884  43732.527725                       28.0
# 91         0.958528  45002.924252                       28.0
# 92         0.675248  43125.218174                       28.0
# 93         0.671141  44371.218297                       28.0
# 94         0.691847  44188.005511                       28.0
#
#     0_ECDF Percentile Count_1  0_ECDF Percentile_0  0_ECDF Percentile_1  \
# 0                       115.0            19.100000            20.890000
# 1                       115.0            20.620000            21.921429
# 2                       115.0            18.000000            18.963333
# 3                       115.0            20.200000            21.666667
# 4                       115.0            20.666667            22.260000
# ..                        ...                  ...                  ...
# 90                      115.0            20.790000            22.356667
# 91                      115.0            23.700000            24.856667
# 92                      115.0            19.760000            21.200000
# 93                      115.0            19.790000            21.000000
# 94                      115.0            19.890000            21.390000
#
#     0_ECDF_0  ...  0_Wavelet variance_0  0_Wavelet variance_1  \
# 0   0.006944  ...              0.088709              0.350769
# 1   0.006944  ...              0.007086              0.051582
# 2   0.006944  ...              0.103434              0.398139
# 3   0.006944  ...              0.008498              0.066407
# 4   0.006944  ...              0.057545              0.249332
# ..       ...  ...                   ...                   ...
# 90  0.006944  ...              0.170029              0.610107
# 91  0.006944  ...              0.191862              0.878697
# 92  0.006944  ...              0.008715              0.110305
# 93  0.006944  ...              0.008138              0.079716
# 94  0.006944  ...              0.074759              0.312477
#
#     0_Wavelet variance_2  0_Wavelet variance_3  0_Wavelet variance_4  \
# 0               0.837373              1.606182              2.691410
# 1               0.174314              0.382618              0.753292
# 2               0.900777              1.589757              2.496321
# 3               0.196446              0.365845              0.577614
# 4               0.635278              1.163635              1.815623
# ..                   ...                   ...                   ...
# 90              1.348842              2.493506              4.271435
# 91              2.476682              4.723998              7.720473
# 92              0.445263              1.096116              2.065490
# 93              0.338323              0.868468              1.738544
# 94              0.807822              1.447529              2.084863
#
#     0_Wavelet variance_5  0_Wavelet variance_6  0_Wavelet variance_7  \
# 0               4.024402              5.566248              7.368580
# 1               1.356199              2.166163              3.108274
# 2               3.717259              5.345789              7.470880
# 3               0.882709              1.371380              2.140581
# 4               2.650329              3.697770              4.979119
# ..                   ...                   ...                   ...
# 90              6.943182             10.709968             15.680119
# 91             11.742593             16.567609             21.763664
# 92              3.253503              4.552441              5.902513
# 93              3.025818              4.776782              6.949264
# 94              2.605486              2.980625              3.285842
#
#     0_Wavelet variance_8  0_Zero crossing rate
# 0               9.541954                   0.0
# 1               4.130929                   3.0
# 2              10.164421                   0.0
# 3               3.259513                   3.0
# 4               6.549902                   2.0
# ..                   ...                   ...
# 90             21.868972                   0.0
# 91             27.119138                   0.0
# 92              7.272874                   6.0
# 93              9.396558                   6.0
# 94              3.619677                   0.0
#
# [95 rows x 4944 columns]

# %%
X_test_features = []
for dim in tqdm(range(X_test.shape[1])): #iterate over dimensions
    temp_features = tsfel.time_series_features_extractor(cfg, [X_test.iloc[i, dim] for i in range(X_test.shape[0])], fs=fs)
    X_test_features.append(temp_features)

X_test_features = pd.concat(X_test_features, axis=1)
X_test_features
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='42'
#                   max='42',
#                   style='width: 25%',
#               >
#                   42
#               </progress>
#   4%|▍         | 1/24 [00:19<07:39, 19.98s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='42'
#                   max='42',
#                   style='width: 25%',
#               >
#                   42
#               </progress>
#   8%|▊         | 2/24 [00:51<09:53, 26.97s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='42'
#                   max='42',
#                   style='width: 25%',
#               >
#                   42
#               </progress>
#  12%|█▎        | 3/24 [01:02<06:54, 19.74s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='42'
#                   max='42',
#                   style='width: 25%',
#               >
#                   42
#               </progress>
#  17%|█▋        | 4/24 [01:17<05:57, 17.87s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='42'
#                   max='42',
#                   style='width: 25%',
#               >
#                   42
#               </progress>
#  21%|██        | 5/24 [01:28<04:51, 15.36s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='42'
#                   max='42',
#                   style='width: 25%',
#               >
#                   42
#               </progress>
#  25%|██▌       | 6/24 [01:41<04:17, 14.32s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='42'
#                   max='42',
#                   style='width: 25%',
#               >
#                   42
#               </progress>
#  29%|██▉       | 7/24 [02:13<05:44, 20.29s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='42'
#                   max='42',
#                   style='width: 25%',
#               >
#                   42
#               </progress>
#  33%|███▎      | 8/24 [02:46<06:28, 24.27s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='42'
#                   max='42',
#                   style='width: 25%',
#               >
#                   42
#               </progress>
#  38%|███▊      | 9/24 [03:14<06:23, 25.54s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='42'
#                   max='42',
#                   style='width: 25%',
#               >
#                   42
#               </progress>
#  42%|████▏     | 10/24 [03:25<04:52, 20.91s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='42'
#                   max='42',
#                   style='width: 25%',
#               >
#                   42
#               </progress>
#  46%|████▌     | 11/24 [03:35<03:48, 17.60s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='42'
#                   max='42',
#                   style='width: 25%',
#               >
#                   42
#               </progress>
#  50%|█████     | 12/24 [03:46<03:05, 15.47s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='42'
#                   max='42',
#                   style='width: 25%',
#               >
#                   42
#               </progress>
#  54%|█████▍    | 13/24 [03:57<02:37, 14.32s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='42'
#                   max='42',
#                   style='width: 25%',
#               >
#                   42
#               </progress>
#  58%|█████▊    | 14/24 [04:11<02:21, 14.11s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='42'
#                   max='42',
#                   style='width: 25%',
#               >
#                   42
#               </progress>
#  62%|██████▎   | 15/24 [04:20<01:53, 12.64s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='42'
#                   max='42',
#                   style='width: 25%',
#               >
#                   42
#               </progress>
#  67%|██████▋   | 16/24 [04:45<02:09, 16.23s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='42'
#                   max='42',
#                   style='width: 25%',
#               >
#                   42
#               </progress>
#  71%|███████   | 17/24 [05:15<02:24, 20.57s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='42'
#                   max='42',
#                   style='width: 25%',
#               >
#                   42
#               </progress>
#  75%|███████▌  | 18/24 [05:46<02:21, 23.63s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='42'
#                   max='42',
#                   style='width: 25%',
#               >
#                   42
#               </progress>
#  79%|███████▉  | 19/24 [06:01<01:44, 20.88s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='42'
#                   max='42',
#                   style='width: 25%',
#               >
#                   42
#               </progress>
#  83%|████████▎ | 20/24 [06:10<01:10, 17.51s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='42'
#                   max='42',
#                   style='width: 25%',
#               >
#                   42
#               </progress>
#  88%|████████▊ | 21/24 [06:20<00:45, 15.27s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='42'
#                   max='42',
#                   style='width: 25%',
#               >
#                   42
#               </progress>
#  92%|█████████▏| 22/24 [06:31<00:27, 13.77s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='42'
#                   max='42',
#                   style='width: 25%',
#               >
#                   42
#               </progress>
#  96%|█████████▌| 23/24 [06:40<00:12, 12.34s/it]
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='42'
#                   max='42',
#                   style='width: 25%',
#               >
#                   42
#               </progress>
# 100%|██████████| 24/24 [06:48<00:00, 17.02s/it]
# *** Feature extraction finished ***
#     0_Absolute energy  0_Area under the curve  0_Autocorrelation  \
# 0        71524.253008            1.990781e+06       71524.253008
# 1        64108.213432            1.885295e+06       64108.213432
# 2        61961.945464            1.851379e+06       61961.945464
# 3        71460.083111            1.990531e+06       71460.083111
# 4        68269.850070            1.945298e+06       68269.850070
# 5        63988.100356            1.883591e+06       63988.100356
# 6        73795.821494            2.022909e+06       73795.821494
# 7        67029.407890            1.926739e+06       67029.407890
# 8        63472.030235            1.875352e+06       63472.030235
# 9        67221.050925            1.929600e+06       67221.050925
# 10       67058.665081            1.927756e+06       67058.665081
# 11       64337.242114            1.888771e+06       64337.242114
# 12       66723.258606            1.923001e+06       66723.258606
# 13       90891.774444            2.245009e+06       90891.774444
# 14       70614.693539            1.978008e+06       70614.693539
# 15       64178.524335            1.884777e+06       64178.524335
# 16       64838.378178            1.895232e+06       64838.378178
# 17       71347.793347            1.989080e+06       71347.793347
# 18       64994.426981            1.898130e+06       64994.426981
# 19       73173.321214            2.013598e+06       73173.321214
# 20       69440.172987            1.961734e+06       69440.172987
# 21       62516.413081            1.860972e+06       62516.413081
# 22       68583.754851            1.950215e+06       68583.754851
# 23       63022.935536            1.868217e+06       63022.935536
# 24       50575.003670            1.673947e+06       50575.003670
# 25       55098.244789            1.746950e+06       55098.244789
# 26       69885.212953            1.967907e+06       69885.212953
# 27       68045.870814            1.942118e+06       68045.870814
# 28       79098.807900            2.094380e+06       79098.807900
# 29       66690.379183            1.922266e+06       66690.379183
# 30       66220.815217            1.916102e+06       66220.815217
# 31       70873.912881            1.981842e+06       70873.912881
# 32       63139.946372            1.870015e+06       63139.946372
# 33       62964.549890            1.867685e+06       62964.549890
# 34       70248.130294            1.972859e+06       70248.130294
# 35       50099.088856            1.665526e+06       50099.088856
# 36       72483.029403            2.004559e+06       72483.029403
# 37       87445.740747            2.202309e+06       87445.740747
# 38       61726.801856            1.849061e+06       61726.801856
# 39       57190.151059            1.780601e+06       57190.151059
# 40       53829.824587            1.727380e+06       53829.824587
# 41       82717.846056            2.141376e+06       82717.846056
#
#     0_Average power    0_Centroid  0_ECDF Percentile Count_0  \
# 0          0.800271  43295.717355                      28.00
# 1          0.717295  44389.059028                      28.00
# 2          0.693281  42018.957996                      28.00
# 3          0.799553  44446.031696                      28.00
# 4          0.763858  44687.099286                      28.00
# 5          0.715951  43841.725777                      28.00
# 6          0.825688  44407.770747                      28.00
# 7          0.749979  43192.828167                      28.00
# 8          0.710177  43840.848187                      28.00
# 9          0.752124  42757.581412                      28.00
# 10         0.750307  44536.367307                      28.00
# 11         0.719857  44331.176998                      28.00
# 12         0.746554  44707.173976                      28.00
# 13         1.016971  44633.408059                      28.00
# 14         0.790094  44429.671145                      28.00
# 15         0.718081  44020.412577                      28.00
# 16         0.725464  44541.408554                      28.00
# 17         0.798297  43805.555382                      28.00
# 18         0.727210  43546.186843                      28.00
# 19         0.818722  43429.193530                      28.00
# 20         0.776953  43697.346208                      28.00
# 21         0.699484  44348.216602                      28.00
# 22         0.767371  43678.003500                      28.00
# 23         0.705152  43273.486099                      28.00
# 24         0.565874  42923.184256                      28.00
# 25         0.616484  44392.871667                      28.00
# 26         0.781932  43659.632582                      28.00
# 27         0.761352  44797.391106                      28.00
# 28         0.885022  44240.292867                      28.00
# 29         0.746186  44524.044888                      28.00
# 30         0.740932  43935.856788                      28.00
# 31         0.792995  44609.589739                      28.00
# 32         0.706461  43430.653128                      28.00
# 33         0.704498  43390.671852                      28.00
# 34         0.785993  44180.840582                      28.00
# 35         0.560549  44467.171077                      28.00
# 36         0.810999  44097.958324                      28.00
# 37         0.978414  44493.365201                      28.00
# 38         0.690650  44797.415696                      28.00
# 39         0.639890  43619.362884                      28.00
# 40         0.602292  43889.436136                      28.00
# 41         0.925514  43956.285539                      24.39
#
#     0_ECDF Percentile Count_1  0_ECDF Percentile_0  0_ECDF Percentile_1  \
# 0                      115.00            21.426667            23.066667
# 1                      115.00            20.675000            21.500000
# 2                      115.00            19.500000            22.000000
# 3                      115.00            21.790000            22.600000
# 4                      115.00            21.323333            22.200000
# 5                      115.00            20.600000            21.500000
# 6                      115.00            22.290000            22.890000
# 7                      115.00            20.790000            22.500000
# 8                      115.00            20.200000            21.600000
# 9                      115.00            20.700000            22.500000
# 10                     115.00            20.926667            22.166667
# 11                     115.00            20.600000            21.600000
# 12                     115.00            21.000000            22.000000
# 13                     115.00            24.790000            25.500000
# 14                     115.00            21.390000            22.790000
# 15                     115.00            20.200000            21.926667
# 16                     115.00            20.600000            21.790000
# 17                     115.00            21.890000            22.823333
# 18                     115.00            20.790000            21.790000
# 19                     115.00            21.890000            23.290000
# 20                     115.00            21.390000            22.600000
# 21                     115.00            20.066667            21.533333
# 22                     115.00            21.260000            22.290000
# 23                     115.00            20.100000            21.760000
# 24                     115.00            18.000000            19.426667
# 25                     115.00            18.890000            20.133333
# 26                     115.00            21.323333            22.700000
# 27                     115.00            21.100000            22.290000
# 28                     115.00            23.200000            23.790000
# 29                     115.00            20.890000            22.200000
# 30                     115.00            21.000000            22.000000
# 31                     115.00            21.600000            22.700000
# 32                     115.00            20.100000            21.600000
# 33                     115.00            20.166667            21.700000
# 34                     115.00            21.290000            22.700000
# 35                     115.00            17.890000            19.550000
# 36                     115.00            22.000000            22.890000
# 37                     115.00            24.499091            24.767273
# 38                     115.00            20.166667            21.100000
# 39                     115.00            19.426667            20.500000
# 40                     115.00            19.000000            19.790000
# 41                      24.39            24.390000            24.390000
#
#     0_ECDF_0  ...  0_Wavelet variance_0  0_Wavelet variance_1  \
# 0   0.006944  ...              0.241875              0.965049
# 1   0.006944  ...              0.073847              0.299108
# 2   0.006944  ...              0.075609              0.278831
# 3   0.006944  ...              0.290310              1.353879
# 4   0.006944  ...              0.288321              1.445026
# 5   0.006944  ...              0.016955              0.149204
# 6   0.006944  ...              0.086887              0.440330
# 7   0.006944  ...              0.400212              1.384173
# 8   0.006944  ...              0.015678              0.103571
# 9   0.006944  ...              0.067502              0.246967
# 10  0.006944  ...              0.031612              0.134646
# 11  0.006944  ...              0.108442              0.480864
# 12  0.006944  ...              0.183203              0.709806
# 13  0.006944  ...              0.867229              3.337296
# 14  0.006944  ...              0.119438              0.650153
# 15  0.006944  ...              0.007751              0.044040
# 16  0.006944  ...              0.063424              0.419912
# 17  0.006944  ...              0.276304              1.044209
# 18  0.006944  ...              0.128893              0.494476
# 19  0.006944  ...              0.119669              0.683059
# 20  0.006944  ...              0.034107              0.242076
# 21  0.006944  ...              0.070073              0.404144
# 22  0.006944  ...              0.132815              0.513885
# 23  0.006944  ...              0.060867              0.236047
# 24  0.006944  ...              0.066128              0.248385
# 25  0.006944  ...              0.005528              0.042115
# 26  0.006944  ...              0.341831              1.229766
# 27  0.006944  ...              0.115867              0.518800
# 28  0.006944  ...              0.340860              1.215087
# 29  0.006944  ...              0.105045              0.428314
# 30  0.006944  ...              0.058391              0.269055
# 31  0.006944  ...              0.053221              0.317326
# 32  0.006944  ...              0.023618              0.100200
# 33  0.006944  ...              0.008589              0.077384
# 34  0.006944  ...              0.089442              0.427263
# 35  0.006944  ...              0.038182              0.229994
# 36  0.006944  ...              0.315865              1.188684
# 37  0.006944  ...              0.914680              3.216626
# 38  0.006944  ...              0.122131              0.625263
# 39  0.006944  ...              0.005525              0.046026
# 40  0.006944  ...              0.013310              0.060833
# 41  0.006944  ...              0.247288              0.983047
#
#     0_Wavelet variance_2  0_Wavelet variance_3  0_Wavelet variance_4  \
# 0               2.240252              4.072122              6.504458
# 1               0.714726              1.342794              2.184683
# 2               0.628721              1.131801              1.832968
# 3               3.016232              5.062382              7.894164
# 4               4.382131              8.112324             11.191746
# 5               0.454327              0.788583              1.061056
# 6               1.365214              2.432054              3.365505
# 7               2.932352              5.036449              7.671278
# 8               0.327738              0.658878              1.047943
# 9               0.534050              0.942795              1.510915
# 10              0.308169              0.515205              0.721649
# 11              1.059594              1.794427              2.683845
# 12              1.817545              3.526696              5.706339
# 13              8.481768             15.374615             21.866128
# 14              1.834153              3.454872              5.522252
# 15              0.114654              0.232314              0.414488
# 16              1.139313              2.015481              3.089186
# 17              2.295891              4.117766              6.547118
# 18              1.046797              1.711625              2.554186
# 19              2.053932              3.635953              4.998521
# 20              0.960997              2.372927              4.495068
# 21              1.306541              2.849068              4.847447
# 22              1.191547              1.966543              2.678580
# 23              0.496708              0.862501              1.398838
# 24              0.558125              0.966468              1.385236
# 25              0.152442              0.381517              0.793968
# 26              2.747084              4.826429              7.419714
# 27              1.407987              2.911253              4.990965
# 28              2.636654              4.668923              7.349966
# 29              0.947713              1.562855              2.246521
# 30              0.548540              0.853166              1.272176
# 31              0.899100              1.873255              3.195488
# 32              0.255947              0.512127              0.887868
# 33              0.300983              0.707502              1.276383
# 34              1.018939              1.885108              2.988942
# 35              0.616647              1.253222              2.063882
# 36              2.783209              5.069700              7.969329
# 37              7.076195             12.203656             18.091937
# 38              1.862655              3.524395              5.083760
# 39              0.156101              0.379736              0.754617
# 40              0.193985              0.450003              0.816573
# 41              2.593467              4.902592              7.527934
#
#     0_Wavelet variance_5  0_Wavelet variance_6  0_Wavelet variance_7  \
# 0               9.444516             12.839085             16.709848
# 1               3.207082              4.314118              5.432603
# 2               2.810014              4.079732              5.555220
# 3              12.188465             18.009520             24.840950
# 4              13.816890             17.103168             22.207224
# 5               1.304067              1.572633              1.885839
# 6               4.436695              5.915138              7.848800
# 7              10.750996             14.247490             18.228435
# 8               1.492794              1.985035              2.491999
# 9               2.280523              3.259235              4.461012
# 10              0.924265              1.157266              1.503174
# 11              3.677748              4.786848              6.073651
# 12              8.235532             10.939712             13.596326
# 13             27.205880             31.942423             36.674588
# 14              8.157519             11.248581             14.581147
# 15              0.680903              1.050689              1.539257
# 16              4.411749              5.932999              7.654284
# 17              9.271728             11.931993             14.324416
# 18              3.632317              4.979271              6.710455
# 19              6.045936              6.716235              7.038047
# 20              7.235369             10.256940             13.121703
# 21              7.053178              9.443894             12.212563
# 22              3.338669              3.918145              4.396849
# 23              2.132449              3.042527              4.056915
# 24              1.748828              2.097731              2.498447
# 25              1.439177              2.322034              3.417623
# 26             10.542153             14.017174             17.542852
# 27              7.361631              9.714857             11.874702
# 28             10.468576             13.732625             17.124085
# 29              3.073899              4.204051              5.788467
# 30              1.769632              2.282304              2.842820
# 31              4.598128              5.933203              7.312881
# 32              1.405418              2.112161              3.055323
# 33              1.999627              2.871202              3.869011
# 34              4.397827              6.130547              8.030078
# 35              2.907087              3.792284              4.741838
# 36             11.434769             15.598301             20.627104
# 37             24.459182             31.331085             38.789217
# 38              6.421231              7.764011              9.526968
# 39              1.258950              1.843307              2.464965
# 40              1.252459              1.732153              2.255063
# 41             10.515810             14.067827             18.059273
#
#     0_Wavelet variance_8  0_Zero crossing rate
# 0              21.170486                   0.0
# 1               6.578164                   1.0
# 2               7.080441                   0.0
# 3              32.115048                   0.0
# 4              30.020994                   0.0
# 5               2.267717                   5.0
# 6              10.174418                   0.0
# 7              22.782810                   0.0
# 8               2.996580                   0.0
# 9               5.926001                   0.0
# 10              2.054280                   0.0
# 11              7.639188                   0.0
# 12             16.010474                   0.0
# 13             41.546819                   0.0
# 14             18.052951                   0.0
# 15              2.159243                   2.0
# 16              9.635434                   2.0
# 17             16.358404                   0.0
# 18              8.995665                   0.0
# 19              7.194206                   0.0
# 20             15.555323                   5.0
# 21             15.418714                   2.0
# 22              4.805133                   0.0
# 23              5.068271                   0.0
# 24              2.969093                   0.0
# 25              4.693651                   2.0
# 26             20.868770                   0.0
# 27             13.835533                   2.0
# 28             20.934236                   0.0
# 29              7.924669                   0.0
# 30              3.545700                   0.0
# 31              8.943163                   1.0
# 32              4.253740                   6.0
# 33              4.971792                   4.0
# 34              9.822868                   5.0
# 35              5.655687                   0.0
# 36             26.594417                   0.0
# 37             46.854903                   0.0
# 38             12.096418                   7.0
# 39              3.090895                   7.0
# 40              2.815785                   3.0
# 41             22.029129                   0.0
#
# [42 rows x 4944 columns]

# %%
# find columns where train_features contains NaN values
nan_columns = X_train_features.columns[X_train_features.isna().any()].tolist()
X_train_features.drop(nan_columns, axis=1, inplace=True)

# %%
X_test_features.drop(nan_columns, axis=1, inplace=True)

# %%
X_test_features.shape
# Out:
# (42, 4896)

# %%
zero_std_features = X_train_features.columns[X_train_features.std() ==0]
num_zero_std_features = len(zero_std_features)

print(f"Number of features with standard deviation equal to zero: {num_zero_std_features}")
print("Features with standard deviation equal to zero:")
print(zero_std_features)
# Out:
# Number of features with standard deviation equal to zero: 480
# Features with standard deviation equal to zero:
# Index(['0_ECDF_0', '0_ECDF_1', '0_ECDF_3', '0_ECDF_4', '0_ECDF_7', '0_ECDF_8',
#        '0_ECDF_9', '0_Histogram_0', '0_Histogram_1', '0_Histogram_2',
#        ...
#        '0_ECDF Percentile Count_0', '0_ECDF Percentile Count_1', '0_ECDF_0',
#        '0_ECDF_1', '0_ECDF_3', '0_ECDF_4', '0_ECDF_7', '0_ECDF_8', '0_ECDF_9',
#        '0_Human range energy'],
#       dtype='object', length=480)

# %%
# X_train_features.drop(zero_std_features, axis=1, inplace= True)
X_test_features.drop(zero_std_features, axis=1, inplace= True)

# corr_features = tsfel.correlated_features(X_train_features)
# len(corr_features)

# %%
X_test_features.shape
# Out:
# (42, 4272)

# %%
from sklearn import preprocessing

# # Highly correlated features are removed
# X_train_features.drop(corr_features, axis=1, inplace=True)
# X_test_features.drop(corr_features, axis=1, inplace=True)


# Normalising Features
scaler = preprocessing.StandardScaler()
nX_train_features = pd.DataFrame(scaler.fit_transform(X_train_features))
nX_test_features = pd.DataFrame(scaler.transform(X_test_features))

# %% [markdown]
# Number of features is way too large, we must do some feature selection

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# Initialize and train a random forest regressor
regressor = RandomForestRegressor(n_estimators=100, random_state=42)
regressor.fit(nX_train_features, y_train)

# Make predictions on the test set and evaluate the model
y_pred = regressor.predict(nX_test_features)
mse = mean_squared_error(y_test, y_pred)

# Results
mse
# Out:
# 4.944411079523807

# %%
y_pred_train = regressor.predict(nX_train_features)
plt.plot(y_pred_train, label = 'pred_train')
plt.plot(y_train, label='train')
plt.legend()
mse = mean_squared_error(y_train, y_pred_train)
mse
# Out:
# 0.8637737053684206

# %%
plt.plot(y_pred, label = 'pred')
plt.plot(y_test, label='test')
plt.legend()

# %%
feature_names = nX_train_features.columns.tolist()
feature_importances = regressor.feature_importances_

# Sort indices based on feature importance
indices = np.argsort(feature_importances)[::-1]

# Plotting the feature importances with feature names
# Plotting the feature importances for the first 60 features
plt.figure(figsize=(15, 6))
plt.bar(range(60), feature_importances[indices][:60], align="center")
plt.xticks(range(60), [feature_names[i] for i in indices][:60], rotation=45, ha="right")
plt.xlabel("Feature Name")
plt.ylabel("Feature Importance")
plt.title("Random Forest Feature Importances (Top 60)")
plt.tight_layout()
plt.show()

# %%
features=[feature_names[i] for i in indices][:19]

# %%
# %pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\tretec\documents\mva\s1\[ast]\tsfel_review\.venv\lib\site-packages (2.0.3)
# Requirement already satisfied: numpy in c:\users\tretec\documents\mva\s1\[ast]\tsfel_review\.venv\lib\site-packages (from xgboost) (1.26.3)
# Requirement already satisfied: scipy in c:\users\tretec\documents\mva\s1\[ast]\tsfel_review\.venv\lib\site-packages (from xgboost) (1.11.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
param_dist = {
    'n_estimators': [50, 100, 200, 300, 400, 500],
    'learning_rate': [0.01, 0.05, 0.1, 0.15, 0.2],
    'max_depth': [3, 4, 5, 6, 7, 8, 9, 10],
    'colsample_bytree': [0.3, 0.5, 0.7, 1],
    'min_child_weight': [1, 2, 3, 4],
    'subsample': [0.5, 0.7, 1],
    'alpha': [0, 0.1, 0.5, 1]
}
xgb_reg = xgb.XGBRegressor(objective ='reg:squarederror')

random_search = RandomizedSearchCV(xgb_reg, param_distributions=param_dist, 
                                   n_iter=25, scoring='neg_mean_squared_error', 
                                   cv=3, verbose=1, random_state=42)

x_train_post_RF = nX_train_features[features]
x_test_post_RF = nX_test_features[features]

random_search.fit(x_train_post_RF, y_train)

# Make predictions on the test set and evaluate the random_search
y_pred = random_search.predict(x_test_post_RF)
mse = mean_squared_error(y_test, y_pred)

# Results
mse
# Out:
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# 6.007863353410508

# %%
plt.plot(y_pred, label = 'pred')
plt.plot(y_test, label='test')
plt.legend()
